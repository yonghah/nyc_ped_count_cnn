# %% [markdown]
# # Compare two datasets
#
# Let's compare two pedestrian estimations with different methods: field count vs. cnn estimation.

# %%
import pandas as pd
import statsmodels.api as sm
import altair as alt
import scipy
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.graphics.api as smg
import itertools

alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %%
df = pd.read_csv("../data/dataframe/df_count.csv")
df = df.set_index('loc')
df.head()
# Out:
#      count_am_2018  count_md_2018  count_pm_2018  count_all_2018  \
# loc
# 1           1271.0         2933.0         4483.0          3220.6
# 2           1749.0         1880.0         4935.5          3076.0
# 3           2209.0         6639.0         9282.5          6810.4
# 4           1648.0         1508.0         2787.0          2047.6
# 5           1016.0         2513.0         3771.0          2716.8
#
#      count_am_1618  count_md_1618  count_pm_1618  count_all_1618  cnn_count  \
# loc
# 1           1370.6    2814.833333    4512.666667     2989.294118       43.0
# 2           2029.6    2265.666667    5158.166667     3217.117647        5.0
# 3           2502.2    7508.333333   10915.833333     7238.588235       97.0
# 4           2061.8    1483.500000    2974.666667     2179.882353        8.0
# 5           1034.4    2504.000000    3588.833333     2454.647059       39.0
#
#      cnn_sum_02  cnn_sum_05
# loc
# 1     58.994938   51.748607
# 2     11.921850    8.642439
# 3    166.952693  134.381194
# 4     17.379551   12.843091
# 5     67.678092   52.184549

# %% [markdown]
# ## Correlation matrix
# let's make correlation matrix between field counts * cnn counts

# %%
counts_cols = list(df.filter(regex='count_').columns)
cnn_cols = list(df.filter(regex='cnn_').columns)
corrs = []
for pair in itertools.product(counts_cols, cnn_cols):
    record = {}
    record['field'] = pair[0]
    record['cnn'] = pair[1]
    record['corr'] = scipy.stats.pearsonr(df[pair[0]], df[pair[1]])[0]
    corrs.append(record)
df_corr = pd.DataFrame(corrs)
df_corr
# Out:
#              field         cnn      corr
# 0    count_am_2018   cnn_count  0.628479
# 1    count_am_2018  cnn_sum_02  0.644199
# 2    count_am_2018  cnn_sum_05  0.642748
# 3    count_md_2018   cnn_count  0.796910
# 4    count_md_2018  cnn_sum_02  0.806468
# 5    count_md_2018  cnn_sum_05  0.804475
# 6    count_pm_2018   cnn_count  0.792433
# 7    count_pm_2018  cnn_sum_02  0.802684
# 8    count_pm_2018  cnn_sum_05  0.801562
# 9   count_all_2018   cnn_count  0.808568
# 10  count_all_2018  cnn_sum_02  0.819761
# 11  count_all_2018  cnn_sum_05  0.818295
# 12   count_am_1618   cnn_count  0.671531
# 13   count_am_1618  cnn_sum_02  0.682260
# 14   count_am_1618  cnn_sum_05  0.682672
# 15   count_md_1618   cnn_count  0.815585
# 16   count_md_1618  cnn_sum_02  0.822895
# 17   count_md_1618  cnn_sum_05  0.821465
# 18   count_pm_1618   cnn_count  0.812449
# 19   count_pm_1618  cnn_sum_02  0.822164
# 20   count_pm_1618  cnn_sum_05  0.822272
# 21  count_all_1618   cnn_count  0.819550
# 22  count_all_1618  cnn_sum_02  0.829183
# 23  count_all_1618  cnn_sum_05  0.828930

# %%
alt.Chart(df).mark_circle().encode(
    x='cnn_sum_02',
    y='count_all_1618'
).properties(width=400, height=400)
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Comparison across aggregation methods
# CNN on GSV does not seem to predict well on AM field count data.
# No big diference
#
# - across PM or MD
# - 3 year or 1 year
# - CNN aggregation method

# %%
alt.Chart(df_corr).mark_bar().encode(
    x='cnn:N',
    y='corr:Q',
    color='cnn:N',
    column='field:N'
)
# Out:
# alt.Chart(...)
